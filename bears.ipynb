# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.4.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 13.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting jupyterlab-server<3,>=2.3.0
#   Downloading jupyterlab_server-2.16.5-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 6.0 MB/s eta 0:00:00
# Collecting jupyter-client<=7.4.1,>=6.1.3
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.11.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from voila) (5.1.0)
# Collecting jupyter-server<2.0.0,>=1.18
#   Downloading jupyter_server-1.23.4-py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from voila) (7.2.6)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from voila) (0.7.2)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from voila) (5.7.1)
# Requirement already satisfied: websockets>=9.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from voila) (10.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (24.0.1)
# Requirement already satisfied: tornado>=6.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (6.2)
# Requirement already satisfied: entrypoints in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-core>=4.11.0->voila) (2.6.0)
# Requirement already satisfied: jinja2 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.1.2)
# Requirement already satisfied: prometheus-client in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.15.0)
# Requirement already satisfied: Send2Trash in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (5.7.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.6.2)
# Requirement already satisfied: websocket-client in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.4.2)
# Requirement already satisfied: argon2-cffi in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3.0)
# Requirement already satisfied: packaging in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (22.0)
# Collecting babel>=2.10
#   Downloading Babel-2.11.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 13.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting json5>=0.9.0
#   Downloading json5-0.9.10-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=2.28 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.28.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.17.3)
# Requirement already satisfied: markupsafe>=2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.2.2)
# Requirement already satisfied: bleach in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (5.0.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.13.0)
# Requirement already satisfied: defusedxml in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.4)
# Requirement already satisfied: tinycss2 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: idna>=2.8 in /home/kali/mambaforge/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in /home/kali/mambaforge/lib/python3.10/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2022.6)
# Requirement already satisfied: attrs>=17.4.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.19.2)
# Requirement already satisfied: fastjsonschema in /home/kali/mambaforge/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=1.18->voila) (2.16.2)
# Requirement already satisfied: six>=1.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client<=7.4.1,>=6.1.3->voila) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.11)
# Requirement already satisfied: ptyprocess in /home/kali/mambaforge/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=1.18->voila) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/kali/mambaforge/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/kali/mambaforge/lib/python3.10/site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.15.1)
# Requirement already satisfied: pycparser in /home/kali/mambaforge/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.21)
# Installing collected packages: json5, babel, jupyter-client, jupyter-server, jupyterlab-server, voila
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.8
#     Uninstalling jupyter_client-7.4.8:
#       Successfully uninstalled jupyter_client-7.4.8
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter_server 2.0.1
#     Uninstalling jupyter_server-2.0.1:
#       Successfully uninstalled jupyter_server-2.0.1
# Successfully installed babel-2.11.0 json5-0.9.10 jupyter-client-7.4.1 jupyter-server-1.23.4 jupyterlab-server-2.16.5 voila-0.4.0
# Enabling: voila
# - Writing config: /home/kali/mambaforge/etc/jupyter
#     - Validating...
#       voila 0.4.0 OK

# %%
! pip install fastbook
! [ -e /content ] && pip install -Uqq fastbook
# !pip install -U duckduckgo_search
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.vision.widgets import *
from fastai.data.all import *
from fastai.vision.all import *
import urllib
import fastcore
from duckduckgo_search import ddg_images
# Out:
# Requirement already satisfied: fastbook in /home/kali/mambaforge/lib/python3.10/site-packages (0.0.29)
# Requirement already satisfied: datasets in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (2.7.1)
# Requirement already satisfied: transformers in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (4.25.1)
# Requirement already satisfied: graphviz in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (0.20.1)
# Requirement already satisfied: sentencepiece in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (0.1.97)
# Requirement already satisfied: fastai>=2.6 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (2.7.10)
# Requirement already satisfied: packaging in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (22.0)
# Requirement already satisfied: ipywidgets<8 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (7.7.2)
# Requirement already satisfied: requests in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (2.28.1)
# Requirement already satisfied: pandas in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (1.5.2)
# Requirement already satisfied: pip in /home/kali/mambaforge/lib/python3.10/site-packages (from fastbook) (22.3.1)
# Requirement already satisfied: matplotlib in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (3.6.2)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (1.5.27)
# Requirement already satisfied: torchvision>=0.8.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (0.14.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: pillow>6.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (9.2.0)
# Requirement already satisfied: torch<1.14,>=1.7 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (1.13.0)
# Requirement already satisfied: pyyaml in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (6.0)
# Requirement already satisfied: scikit-learn in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: scipy in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (1.9.3)
# Requirement already satisfied: spacy<4 in /home/kali/mambaforge/lib/python3.10/site-packages (from fastai>=2.6->fastbook) (3.4.3)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (3.6.1)
# Requirement already satisfied: ipython>=4.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipywidgets<8->fastbook) (8.7.0)
# Requirement already satisfied: responses<0.19 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (10.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (0.11.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (2022.11.0)
# Requirement already satisfied: aiohttp in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (3.8.3)
# Requirement already satisfied: dill<0.3.7 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (4.64.1)
# Requirement already satisfied: xxhash in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (3.1.0)
# Requirement already satisfied: multiprocess in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (0.70.14)
# Requirement already satisfied: numpy>=1.17 in /home/kali/mambaforge/lib/python3.10/site-packages (from datasets->fastbook) (1.23.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests->fastbook) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests->fastbook) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests->fastbook) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests->fastbook) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from pandas->fastbook) (2022.6)
# Requirement already satisfied: filelock in /home/kali/mambaforge/lib/python3.10/site-packages (from transformers->fastbook) (3.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/kali/mambaforge/lib/python3.10/site-packages (from transformers->fastbook) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from transformers->fastbook) (0.13.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (6.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from aiohttp->datasets->fastbook) (1.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets->fastbook) (4.4.0)
# Requirement already satisfied: comm>=0.1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.1.2)
# Requirement already satisfied: psutil in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (5.9.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (7.4.1)
# Requirement already satisfied: pyzmq>=17 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (1.6.4)
# Requirement already satisfied: stack-data in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.2)
# Requirement already satisfied: pickleshare in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.18.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.36)
# Requirement already satisfied: backcall in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: decorator in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (4.8.0)
# Requirement already satisfied: six>=1.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->fastbook) (1.16.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.5)
# Requirement already satisfied: jinja2 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.10)
# Requirement already satisfied: setuptools in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (65.5.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.10.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from spacy<4->fastai>=2.6->fastbook) (8.1.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from matplotlib->fastai>=2.6->fastbook) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from matplotlib->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /home/kali/mambaforge/lib/python3.10/site-packages (from matplotlib->fastai>=2.6->fastbook) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from scikit-learn->fastai>=2.6->fastbook) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8->fastbook) (5.1.0)
# Requirement already satisfied: entrypoints in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: nbformat in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (7.2.6)
# Requirement already satisfied: argon2-cffi in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.4.8)
# Requirement already satisfied: prometheus-client in /home/kali/mambaforge/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.15.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from pathy>=0.3.5->spacy<4->fastai>=2.6->fastbook) (5.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.0)
# Requirement already satisfied: wcwidth in /home/kali/mambaforge/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/kali/mambaforge/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai>=2.6->fastbook) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai>=2.6->fastbook) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.2.1)
# Requirement already satisfied: pure-eval in /home/kali/mambaforge/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (1.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8->fastbook) (2.6.0)
# Requirement already satisfied: jupyter-server>=1.8 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: bleach in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (5.0.1)
# Requirement already satisfied: defusedxml in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.7.2)
# Requirement already satisfied: tinycss2 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.11.1)
# Requirement already satisfied: fastjsonschema in /home/kali/mambaforge/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/kali/mambaforge/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/kali/mambaforge/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.19.2)
# Requirement already satisfied: websocket-client in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/kali/mambaforge/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/kali/mambaforge/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/kali/mambaforge/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: pycparser in /home/kali/mambaforge/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.21)
# Requirement already satisfied: duckduckgo_search in /home/kali/mambaforge/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: click>=8.1.3 in /home/kali/mambaforge/lib/python3.10/site-packages (from duckduckgo_search) (8.1.3)
# Requirement already satisfied: requests>=2.28.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from duckduckgo_search) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28.1->duckduckgo_search) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28.1->duckduckgo_search) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28.1->duckduckgo_search) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kali/mambaforge/lib/python3.10/site-packages (from requests>=2.28.1->duckduckgo_search) (1.26.11)

# %%
path = Path()
path.ls(file_exts='.pkl')
learn_inference=load_learner(path/'Bears/bears.pkl')
out_pl = widgets.Output()
out_pl.clear_output()
btn_upload = widgets.FileUpload()
label_pred = widgets.Label()
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inference.predict(img)
    label_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
btn_run = widgets.Button(description='Classify')
btn_run.on_click(on_click_classify)
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, label_pred])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 path = Path()
#       2 path.ls(file_exts='.pkl')
#       3 learn_inference=load_learner(path/'Bears/bears.pkl')
#
# NameError: name 'Path' is not defined
